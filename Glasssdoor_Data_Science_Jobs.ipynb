# %% [markdown]
# ### Importing packages

# %%
import pandas as pd
import datetime as dt
import numpy as np
import missingno as msno

# %% [markdown]
# ### reading data and introductory cleaning

# %%
#reading the data into jobs dataframe
jobs=pd.read_csv('Uncleaned_DS_jobs.csv')

# %%
# information on the dataframe
jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              672 non-null    int64
#  1   Job Title          672 non-null    object
#  2   Salary Estimate    672 non-null    object
#  3   Job Description    672 non-null    object
#  4   Rating             672 non-null    float64
#  5   Company Name       672 non-null    object
#  6   Location           672 non-null    object
#  7   Headquarters       672 non-null    object
#  8   Size               672 non-null    object
#  9   Founded            672 non-null    int64
#  10  Type of ownership  672 non-null    object
#  11  Industry           672 non-null    object
#  12  Sector             672 non-null    object
#  13  Revenue            672 non-null    object
#  14  Competitors        672 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 78.9+ KB

# %% [markdown]
# ### Uncleaned dataframe contain 672 rows

# %%
# an overview of the contents of the dataframe
jobs
# Out:
#      index          Job Title               Salary Estimate  \
# 0        0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1        1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2        2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3        3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4        4     Data Scientist  $137K-$171K (Glassdoor est.)
# ..     ...                ...                           ...
# 667    667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668    668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669    669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670    670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671    671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 667  Summary\n\nWe’re looking for a data scientist ...     3.6
# 668  Job Description\nBecome a thought leader withi...    -1.0
# 669  Join a thriving company that is changing the w...    -1.0
# 670  100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671  Description\n\nThe Data Scientist will be part...     2.7
#
#                   Company Name           Location            Headquarters  \
# 0             Healthfirst\n3.1       New York, NY            New York, NY
# 1                 ManTech\n4.2      Chantilly, VA             Herndon, VA
# 2          Analysis Group\n3.8         Boston, MA              Boston, MA
# 3                 INFICON\n3.5         Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions\n2.9       New York, NY            New York, NY
# ..                         ...                ...                     ...
# 667              TRANZACT\n3.6       Fort Lee, NJ            Fort Lee, NJ
# 668                       JKGT  San Francisco, CA                      -1
# 669                 AccessHope      Irwindale, CA                      -1
# 670  ChaTeck Incorporated\n5.0  San Francisco, CA         Santa Clara, CA
# 671         1-800-Flowers\n2.7       New York, NY         Carle Place, NY
#
#                         Size  Founded        Type of ownership  \
# 0     1001 to 5000 employees     1993   Nonprofit Organization
# 1    5001 to 10000 employees     1968         Company - Public
# 2     1001 to 5000 employees     1981  Private Practice / Firm
# 3      501 to 1000 employees     2000         Company - Public
# 4        51 to 200 employees     1998        Company - Private
# ..                       ...      ...                      ...
# 667   1001 to 5000 employees     1989        Company - Private
# 668                       -1       -1                       -1
# 669                       -1       -1                       -1
# 670        1 to 50 employees       -1        Company - Private
# 671   1001 to 5000 employees     1976         Company - Public
#
#                                   Industry             Sector  \
# 0                       Insurance Carriers          Insurance
# 1                   Research & Development  Business Services
# 2                               Consulting  Business Services
# 3    Electrical & Electronic Manufacturing      Manufacturing
# 4                  Advertising & Marketing  Business Services
# ..                                     ...                ...
# 667                Advertising & Marketing  Business Services
# 668                                     -1                 -1
# 669                                     -1                 -1
# 670                Advertising & Marketing  Business Services
# 671                              Wholesale  Business Services
#
#                         Revenue  \
# 0      Unknown / Non-Applicable
# 1        $1 to $2 billion (USD)
# 2    $100 to $500 million (USD)
# 3    $100 to $500 million (USD)
# 4      Unknown / Non-Applicable
# ..                          ...
# 667    Unknown / Non-Applicable
# 668                          -1
# 669                          -1
# 670      $1 to $5 million (USD)
# 671      $1 to $2 billion (USD)
#
#                                            Competitors
# 0              EmblemHealth, UnitedHealth Group, Aetna
# 1                                                   -1
# 2                                                   -1
# 3    MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4                 Commerce Signals, Cardlytics, Yodlee
# ..                                                 ...
# 667                                                 -1
# 668                                                 -1
# 669                                                 -1
# 670                                                 -1
# 671                                                 -1
#
# [672 rows x 15 columns]

# %% [markdown]
# ### dataframe has entries of -1 which hints of missing values

# %%
# using the index column that comes with the Dataset comes as the dataframe index
jobs.set_index('index',inplace=True)
jobs
# Out:
#                Job Title               Salary Estimate  \
# index
# 0      Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1         Data Scientist  $137K-$171K (Glassdoor est.)
# 2         Data Scientist  $137K-$171K (Glassdoor est.)
# 3         Data Scientist  $137K-$171K (Glassdoor est.)
# 4         Data Scientist  $137K-$171K (Glassdoor est.)
# ...                  ...                           ...
# 667       Data Scientist  $105K-$167K (Glassdoor est.)
# 668       Data Scientist  $105K-$167K (Glassdoor est.)
# 669       Data Scientist  $105K-$167K (Glassdoor est.)
# 670       Data Scientist  $105K-$167K (Glassdoor est.)
# 671       Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                          Job Description  Rating  \
# index
# 0      Description\n\nThe Senior Data Scientist is re...     3.1
# 1      Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2      Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3      JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4      Data Scientist\nAffinity Solutions / Marketing...     2.9
# ...                                                  ...     ...
# 667    Summary\n\nWe’re looking for a data scientist ...     3.6
# 668    Job Description\nBecome a thought leader withi...    -1.0
# 669    Join a thriving company that is changing the w...    -1.0
# 670    100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671    Description\n\nThe Data Scientist will be part...     2.7
#
#                     Company Name           Location            Headquarters  \
# index
# 0               Healthfirst\n3.1       New York, NY            New York, NY
# 1                   ManTech\n4.2      Chantilly, VA             Herndon, VA
# 2            Analysis Group\n3.8         Boston, MA              Boston, MA
# 3                   INFICON\n3.5         Newton, MA  Bad Ragaz, Switzerland
# 4        Affinity Solutions\n2.9       New York, NY            New York, NY
# ...                          ...                ...                     ...
# 667                TRANZACT\n3.6       Fort Lee, NJ            Fort Lee, NJ
# 668                         JKGT  San Francisco, CA                      -1
# 669                   AccessHope      Irwindale, CA                      -1
# 670    ChaTeck Incorporated\n5.0  San Francisco, CA         Santa Clara, CA
# 671           1-800-Flowers\n2.7       New York, NY         Carle Place, NY
#
#                           Size  Founded        Type of ownership  \
# index
# 0       1001 to 5000 employees     1993   Nonprofit Organization
# 1      5001 to 10000 employees     1968         Company - Public
# 2       1001 to 5000 employees     1981  Private Practice / Firm
# 3        501 to 1000 employees     2000         Company - Public
# 4          51 to 200 employees     1998        Company - Private
# ...                        ...      ...                      ...
# 667     1001 to 5000 employees     1989        Company - Private
# 668                         -1       -1                       -1
# 669                         -1       -1                       -1
# 670          1 to 50 employees       -1        Company - Private
# 671     1001 to 5000 employees     1976         Company - Public
#
#                                     Industry             Sector  \
# index
# 0                         Insurance Carriers          Insurance
# 1                     Research & Development  Business Services
# 2                                 Consulting  Business Services
# 3      Electrical & Electronic Manufacturing      Manufacturing
# 4                    Advertising & Marketing  Business Services
# ...                                      ...                ...
# 667                  Advertising & Marketing  Business Services
# 668                                       -1                 -1
# 669                                       -1                 -1
# 670                  Advertising & Marketing  Business Services
# 671                                Wholesale  Business Services
#
#                           Revenue  \
# index
# 0        Unknown / Non-Applicable
# 1          $1 to $2 billion (USD)
# 2      $100 to $500 million (USD)
# 3      $100 to $500 million (USD)
# 4        Unknown / Non-Applicable
# ...                           ...
# 667      Unknown / Non-Applicable
# 668                            -1
# 669                            -1
# 670        $1 to $5 million (USD)
# 671        $1 to $2 billion (USD)
#
#                                              Competitors
# index
# 0                EmblemHealth, UnitedHealth Group, Aetna
# 1                                                     -1
# 2                                                     -1
# 3      MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4                   Commerce Signals, Cardlytics, Yodlee
# ...                                                  ...
# 667                                                   -1
# 668                                                   -1
# 669                                                   -1
# 670                                                   -1
# 671                                                   -1
#
# [672 rows x 14 columns]

# %% [markdown]
# ## Removing Duplicates

# %%
#viewing completely duplicated rows and sorting according to job title
jobs[jobs.duplicated(keep=False)].sort_values('Job Title')
# Out:
#                        Job Title               Salary Estimate  \
# index
# 361               Data Scientist  $122K-$146K (Glassdoor est.)
# 498               Data Scientist   $95K-$119K (Glassdoor est.)
# 497               Data Scientist   $95K-$119K (Glassdoor est.)
# 496               Data Scientist   $95K-$119K (Glassdoor est.)
# 495               Data Scientist   $95K-$119K (Glassdoor est.)
# 389               Data Scientist  $110K-$163K (Glassdoor est.)
# 388               Data Scientist  $110K-$163K (Glassdoor est.)
# 362               Data Scientist  $122K-$146K (Glassdoor est.)
# 500               Data Scientist   $95K-$119K (Glassdoor est.)
# 360               Data Scientist  $122K-$146K (Glassdoor est.)
# 359               Data Scientist  $122K-$146K (Glassdoor est.)
# 358               Data Scientist  $122K-$146K (Glassdoor est.)
# 357               Data Scientist  $122K-$146K (Glassdoor est.)
# 499               Data Scientist   $95K-$119K (Glassdoor est.)
# 135    Machine Learning Engineer   $90K-$109K (Glassdoor est.)
# 134    Machine Learning Engineer   $90K-$109K (Glassdoor est.)
# 136         Senior Data Engineer   $90K-$109K (Glassdoor est.)
# 131         Senior Data Engineer   $90K-$109K (Glassdoor est.)
#
#                                          Job Description  Rating  \
# index
# 361    Job Overview: The Data Scientist is a key memb...    -1.0
# 498    Job Overview: The Data Scientist is a key memb...    -1.0
# 497    Job Overview: The Data Scientist is a key memb...    -1.0
# 496    Job Overview: The Data Scientist is a key memb...    -1.0
# 495    Job Overview: The Data Scientist is a key memb...    -1.0
# 389    Job Description\nAs a Data Scientist, you will...    -1.0
# 388    Job Description\nAs a Data Scientist, you will...    -1.0
# 362    Job Overview: The Data Scientist is a key memb...    -1.0
# 500    Job Overview: The Data Scientist is a key memb...    -1.0
# 360    Job Overview: The Data Scientist is a key memb...    -1.0
# 359    Job Overview: The Data Scientist is a key memb...    -1.0
# 358    Job Overview: The Data Scientist is a key memb...    -1.0
# 357    Job Overview: The Data Scientist is a key memb...    -1.0
# 499    Job Overview: The Data Scientist is a key memb...    -1.0
# 135    Role Description\nTriplebyte screens and evalu...     3.2
# 134    Role Description\nTriplebyte screens and evalu...     3.2
# 136    Lendio is looking to fill a position for a Sen...     4.9
# 131    Lendio is looking to fill a position for a Sen...     4.9
#
#           Company Name           Location       Headquarters  \
# index
# 361     Hatch Data Inc  San Francisco, CA                 -1
# 498     Hatch Data Inc  San Francisco, CA                 -1
# 497     Hatch Data Inc  San Francisco, CA                 -1
# 496     Hatch Data Inc  San Francisco, CA                 -1
# 495     Hatch Data Inc  San Francisco, CA                 -1
# 389             HireAi  San Francisco, CA                 -1
# 388             HireAi  San Francisco, CA                 -1
# 362     Hatch Data Inc  San Francisco, CA                 -1
# 500     Hatch Data Inc  San Francisco, CA                 -1
# 360     Hatch Data Inc  San Francisco, CA                 -1
# 359     Hatch Data Inc  San Francisco, CA                 -1
# 358     Hatch Data Inc  San Francisco, CA                 -1
# 357     Hatch Data Inc  San Francisco, CA                 -1
# 499     Hatch Data Inc  San Francisco, CA                 -1
# 135    Triplebyte\n3.2             Remote  San Francisco, CA
# 134    Triplebyte\n3.2             Remote  San Francisco, CA
# 136        Lendio\n4.9           Lehi, UT           Lehi, UT
# 131        Lendio\n4.9           Lehi, UT           Lehi, UT
#
#                        Size  Founded  Type of ownership  \
# index
# 361                      -1       -1                 -1
# 498                      -1       -1                 -1
# 497                      -1       -1                 -1
# 496                      -1       -1                 -1
# 495                      -1       -1                 -1
# 389                      -1       -1                 -1
# 388                      -1       -1                 -1
# 362                      -1       -1                 -1
# 500                      -1       -1                 -1
# 360                      -1       -1                 -1
# 359                      -1       -1                 -1
# 358                      -1       -1                 -1
# 357                      -1       -1                 -1
# 499                      -1       -1                 -1
# 135     51 to 200 employees     2015  Company - Private
# 134     51 to 200 employees     2015  Company - Private
# 136    201 to 500 employees     2011  Company - Private
# 131    201 to 500 employees     2011  Company - Private
#
#                            Industry                  Sector  \
# index
# 361                              -1                      -1
# 498                              -1                      -1
# 497                              -1                      -1
# 496                              -1                      -1
# 495                              -1                      -1
# 389                              -1                      -1
# 388                              -1                      -1
# 362                              -1                      -1
# 500                              -1                      -1
# 360                              -1                      -1
# 359                              -1                      -1
# 358                              -1                      -1
# 357                              -1                      -1
# 499                              -1                      -1
# 135    Computer Hardware & Software  Information Technology
# 134    Computer Hardware & Software  Information Technology
# 136                         Lending                 Finance
# 131                         Lending                 Finance
#
#                          Revenue Competitors
# index
# 361                           -1          -1
# 498                           -1          -1
# 497                           -1          -1
# 496                           -1          -1
# 495                           -1          -1
# 389                           -1          -1
# 388                           -1          -1
# 362                           -1          -1
# 500                           -1          -1
# 360                           -1          -1
# 359                           -1          -1
# 358                           -1          -1
# 357                           -1          -1
# 499                           -1          -1
# 135     Unknown / Non-Applicable          -1
# 134     Unknown / Non-Applicable          -1
# 136    $50 to $100 million (USD)          -1
# 131    $50 to $100 million (USD)          -1

# %%
# removing complete duplicates
jobs.drop_duplicates(keep='first',inplace=True)

# %%
# Computing number of complete duplicates cleaned
672-jobs.shape[0]
# Out:
# 13

# %% [markdown]
# ### Thirteen complete duplicates cleaned

# %% [markdown]
# ### Dealing with missing values

# %%
#Changing the -1 entries to represent the missing state of the data
# Thus, treating the -1's in the various columns as null values

for i in jobs.columns:
    jobs.loc[jobs[i]=='-1',i]=np.nan
    jobs.loc[jobs[i]==-1,i]=np.nan

# %%
# Finding the total number of missing values
jobs.isnull().sum().sum()
# Out:
# 822

# %% [markdown]
# ### Dataframe contains 822 missing values

# %%
# how are these missing values distributed in terms of the columns in which they are found
jobs.isnull().sum()
# Out:
# Job Title              0
# Salary Estimate        0
# Job Description        0
# Rating                39
# Company Name           0
# Location               0
# Headquarters          20
# Size                  16
# Founded              107
# Type of ownership     16
# Industry              60
# Sector                60
# Revenue               16
# Competitors          488
# dtype: int64

# %%
# visualising the missing values to see if there are any patterns
msno.matrix(jobs.sort_values('Rating'))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Dealing with missing values in rating column

# %%
# It is noted that there the rating values are repeated in the Company Name
# The ratings in the Company Name Column will be extracted into a new column and the compared

jobs[['Company Name','Rating in name']]=jobs['Company Name'].str.split('\n',expand=True)

# %%
jobs
# Out:
#                Job Title               Salary Estimate  \
# index
# 0      Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1         Data Scientist  $137K-$171K (Glassdoor est.)
# 2         Data Scientist  $137K-$171K (Glassdoor est.)
# 3         Data Scientist  $137K-$171K (Glassdoor est.)
# 4         Data Scientist  $137K-$171K (Glassdoor est.)
# ...                  ...                           ...
# 667       Data Scientist  $105K-$167K (Glassdoor est.)
# 668       Data Scientist  $105K-$167K (Glassdoor est.)
# 669       Data Scientist  $105K-$167K (Glassdoor est.)
# 670       Data Scientist  $105K-$167K (Glassdoor est.)
# 671       Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                          Job Description  Rating  \
# index
# 0      Description\n\nThe Senior Data Scientist is re...     3.1
# 1      Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2      Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3      JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4      Data Scientist\nAffinity Solutions / Marketing...     2.9
# ...                                                  ...     ...
# 667    Summary\n\nWe’re looking for a data scientist ...     3.6
# 668    Job Description\nBecome a thought leader withi...     NaN
# 669    Join a thriving company that is changing the w...     NaN
# 670    100 Remote Opportunity As an AINLP Data Scient...     5.0
# 671    Description\n\nThe Data Scientist will be part...     2.7
#
#                Company Name           Location            Headquarters  \
# index
# 0               Healthfirst       New York, NY            New York, NY
# 1                   ManTech      Chantilly, VA             Herndon, VA
# 2            Analysis Group         Boston, MA              Boston, MA
# 3                   INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4        Affinity Solutions       New York, NY            New York, NY
# ...                     ...                ...                     ...
# 667                TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                    JKGT  San Francisco, CA                     NaN
# 669              AccessHope      Irwindale, CA                     NaN
# 670    ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671           1-800-Flowers       New York, NY         Carle Place, NY
#
#                           Size  Founded        Type of ownership  \
# index
# 0       1001 to 5000 employees   1993.0   Nonprofit Organization
# 1      5001 to 10000 employees   1968.0         Company - Public
# 2       1001 to 5000 employees   1981.0  Private Practice / Firm
# 3        501 to 1000 employees   2000.0         Company - Public
# 4          51 to 200 employees   1998.0        Company - Private
# ...                        ...      ...                      ...
# 667     1001 to 5000 employees   1989.0        Company - Private
# 668                        NaN      NaN                      NaN
# 669                        NaN      NaN                      NaN
# 670          1 to 50 employees      NaN        Company - Private
# 671     1001 to 5000 employees   1976.0         Company - Public
#
#                                     Industry             Sector  \
# index
# 0                         Insurance Carriers          Insurance
# 1                     Research & Development  Business Services
# 2                                 Consulting  Business Services
# 3      Electrical & Electronic Manufacturing      Manufacturing
# 4                    Advertising & Marketing  Business Services
# ...                                      ...                ...
# 667                  Advertising & Marketing  Business Services
# 668                                      NaN                NaN
# 669                                      NaN                NaN
# 670                  Advertising & Marketing  Business Services
# 671                                Wholesale  Business Services
#
#                           Revenue  \
# index
# 0        Unknown / Non-Applicable
# 1          $1 to $2 billion (USD)
# 2      $100 to $500 million (USD)
# 3      $100 to $500 million (USD)
# 4        Unknown / Non-Applicable
# ...                           ...
# 667      Unknown / Non-Applicable
# 668                           NaN
# 669                           NaN
# 670        $1 to $5 million (USD)
# 671        $1 to $2 billion (USD)
#
#                                              Competitors Rating in name
# index
# 0                EmblemHealth, UnitedHealth Group, Aetna            3.1
# 1                                                    NaN            4.2
# 2                                                    NaN            3.8
# 3      MKS Instruments, Pfeiffer Vacuum, Agilent Tech...            3.5
# 4                   Commerce Signals, Cardlytics, Yodlee            2.9
# ...                                                  ...            ...
# 667                                                  NaN            3.6
# 668                                                  NaN           None
# 669                                                  NaN           None
# 670                                                  NaN            5.0
# 671                                                  NaN            2.7
#
# [659 rows x 15 columns]

# %%
#Cross-validating the contents of Rating with the contents of Rating in name

jobs['Rating in name']=jobs['Rating in name'].astype('float') # converting the entries of the Rating in name column to float dtype

jobs[(jobs['Rating']!=jobs['Rating in name']) & (jobs['Rating in name'].notna())]
# Out:
#                        Job Title               Salary Estimate  \
# index
# 167          Senior Data Analyst  $101K-$165K (Glassdoor est.)
# 179    Machine Learning Engineer    $56K-$97K (Glassdoor est.)
# 308               Data Scientist    $145K-$225K(Employer est.)
#
#                                          Job Description  Rating  \
# index
# 167    Secure our Nation, Ignite your Future\n\nJob S...     4.2
# 179    Returning Candidate? Log back in to the Career...     3.6
# 308    Data Scientist\n\nRequirements\nMS or PhD in C...     5.0
#
#          Company Name           Location   Headquarters  \
# index
# 167          Autodesk  San Francisco, CA    Herndon, VA
# 179           Buckman        Memphis, TN  Arlington, VA
# 308    Kollasoft Inc.       New York, NY     Irving, TX
#
#                           Size  Founded       Type of ownership  \
# index
# 167    5001 to 10000 employees   1968.0        Company - Public
# 179      501 to 1000 employees   1967.0  Nonprofit Organization
# 308                    Unknown      NaN        Company - Public
#
#                      Industry             Sector                    Revenue  \
# index
# 167    Research & Development  Business Services     $1 to $2 billion (USD)
# 179          Federal Agencies         Government  $50 to $100 million (USD)
# 308                       NaN                NaN   Unknown / Non-Applicable
#
#       Competitors  Rating in name
# index
# 167           NaN             4.0
# 179           NaN             3.5
# 308           NaN             3.2

# %% [markdown]
# ### Comparing the rating values in the company name to the rating values in the Rating column, discrepancies have been found in 3 rows where;
# * Autodesk has a 4.2 rating
# * Buckman has a 3.6 rating
# * Kollasoft Inc. has a 5.0 rating

# %% [markdown]
# ### To solve this issue, all other observations of the 3 companies where the are different ratings are considered

# %%
jobs[(jobs['Company Name']=='Autodesk') & (jobs['Rating']!=4.2)]
# Out:
#                       Job Title               Salary Estimate  \
# index
# 72     Principal Data Scientist   $79K-$131K (Glassdoor est.)
# 103       Senior Data Scientist   $99K-$132K (Glassdoor est.)
# 166         Senior Data Analyst  $101K-$165K (Glassdoor est.)
# 447    Principal Data Scientist   $69K-$116K (Glassdoor est.)
# 563        Data Science Manager  $128K-$201K (Glassdoor est.)
# 592       Senior Data Scientist   $80K-$132K (Glassdoor est.)
#
#                                          Job Description  Rating Company Name  \
# index
# 72     Job Requisition ID #\n20WD40121\nJob Title\nPr...     4.0     Autodesk
# 103    Job Requisition ID #\n20WD40666\nJob Title\nSe...     4.0     Autodesk
# 166    Job Requisition ID #\n20WD38079\nJob Title\nSe...     4.0     Autodesk
# 447    Job Requisition ID #\n20WD40121\nJob Title\nPr...     4.0     Autodesk
# 563    Job Requisition ID #\n20WD38093\nJob Title\nDa...     4.0     Autodesk
# 592    Job Requisition ID #\n20WD40666\nJob Title\nSe...     4.0     Autodesk
#
#                 Location    Headquarters                     Size  Founded  \
# index
# 72     San Francisco, CA  San Rafael, CA  5001 to 10000 employees   1982.0
# 103    San Francisco, CA  San Rafael, CA  5001 to 10000 employees   1982.0
# 166    San Francisco, CA  San Rafael, CA  5001 to 10000 employees   1982.0
# 447    San Francisco, CA  San Rafael, CA  5001 to 10000 employees   1982.0
# 563    San Francisco, CA  San Rafael, CA  5001 to 10000 employees   1982.0
# 592    San Francisco, CA  San Rafael, CA  5001 to 10000 employees   1982.0
#
#       Type of ownership                      Industry                  Sector  \
# index
# 72     Company - Public  Computer Hardware & Software  Information Technology
# 103    Company - Public  Computer Hardware & Software  Information Technology
# 166    Company - Public  Computer Hardware & Software  Information Technology
# 447    Company - Public  Computer Hardware & Software  Information Technology
# 563    Company - Public  Computer Hardware & Software  Information Technology
# 592    Company - Public  Computer Hardware & Software  Information Technology
#
#                       Revenue Competitors  Rating in name
# index
# 72     $2 to $5 billion (USD)         NaN             4.0
# 103    $2 to $5 billion (USD)         NaN             4.0
# 166    $2 to $5 billion (USD)         NaN             4.0
# 447    $2 to $5 billion (USD)         NaN             4.0
# 563    $2 to $5 billion (USD)         NaN             4.0
# 592    $2 to $5 billion (USD)         NaN             4.0

# %% [markdown]
# ### This implies that the entry with the first discrepancy doesn't belong to Autodesk

# %%
jobs[(jobs['Rating']==4.2) & (jobs['Headquarters']=='Herndon, VA') & (jobs['Founded']==1968.0) & \
        (jobs['Company Name']!='Autodesk')]['Company Name'].unique()
# Out:
# array(['ManTech'], dtype=object)

# %% [markdown]
# ### It is a row that belongs to ManTech

# %%
# Correcting the company name to ManTech

jobs.loc[(jobs['Rating']==4.2) & (jobs['Headquarters']=='Herndon, VA') & (jobs['Founded']==1968.0), \
        'Company Name']='ManTech'

# %% [markdown]
# ### Repeating for the two other discrepancies

# %%
jobs[(jobs['Company Name']=='Buckman') & (jobs['Rating']!=3.6)]
# Out:
#             Job Title               Salary Estimate  \
# index
# 17     Data Scientist  $137K-$171K (Glassdoor est.)
# 178    Data Scientist    $56K-$97K (Glassdoor est.)
#
#                                          Job Description  Rating Company Name  \
# index
# 17     Job Success Profile\n\nData Scientist\n\nBuckm...     3.5      Buckman
# 178    Job Success Profile\n\nData Scientist\n\nBuckm...     3.5      Buckman
#
#           Location Headquarters                    Size  Founded  \
# index
# 17     Memphis, TN  Memphis, TN  1001 to 5000 employees   1945.0
# 178    Memphis, TN  Memphis, TN  1001 to 5000 employees   1945.0
#
#        Type of ownership                Industry         Sector  \
# index
# 17     Company - Private  Chemical Manufacturing  Manufacturing
# 178    Company - Private  Chemical Manufacturing  Manufacturing
#
#                                 Revenue Competitors  Rating in name
# index
# 17     $500 million to $1 billion (USD)         NaN             3.5
# 178    $500 million to $1 billion (USD)         NaN             3.5

# %%
jobs[(jobs['Rating']==3.6) & (jobs['Headquarters']=='Arlington, VA') & (jobs['Founded']==1967.0) & \
        (jobs['Company Name']!='Buckman')]['Company Name'].unique()
# Out:
# array(['Riverside Research Institute'], dtype=object)

# %% [markdown]
# ### In the second case, the row belongs to Riverside Research Institute

# %%
# Correcting the company name to Riverside Research Institute
jobs.loc[(jobs['Rating']==3.6) & (jobs['Headquarters']=='Arlington, VA') & (jobs['Founded']==1967.0),
     'Company Name']='Riverside Research Institute'

# %%
jobs[(jobs['Company Name']=='Kollasoft Inc.') & (jobs['Rating']!=5.0)]
# Out:
#             Job Title             Salary Estimate  \
# index
# 307    Data Scientist  $145K-$225K(Employer est.)
#
#                                          Job Description  Rating  \
# index
# 307    DATA SCIENTIST REMOTE working with occasional ...     3.2
#
#          Company Name       Location    Headquarters               Size  \
# index
# 307    Kollasoft Inc.  United States  Scottsdale, AZ  1 to 50 employees
#
#        Founded  Type of ownership     Industry                  Sector  \
# index
# 307        NaN  Company - Private  IT Services  Information Technology
#
#                       Revenue Competitors  Rating in name
# index
# 307    $1 to $5 million (USD)         NaN             3.2

# %%
jobs[jobs['Rating']==5.0]
# Out:
#                                          Job Title  \
# index
# 32                                  Data Scientist
# 43                   Scientist - Molecular Biology
# 113                                  Data Engineer
# 118                                  NGS Scientist
# 130                                 Data Scientist
# 144                      Machine Learning Engineer
# 193                                 Data Scientist
# 209     Data Scientist - TS/SCI FSP or CI Required
# 212               Data Scientist - TS/SCI Required
# 227                                 Data Scientist
# 244            Real World Evidence (RWE) Scientist
# 258                                 Data Scientist
# 269        Data Engineer, Digital & Comp Pathology
# 274                                 Data Scientist
# 281                                 Data Scientist
# 284                                 Data Scientist
# 308                                 Data Scientist
# 333                                 Data Scientist
# 349                                 Data Scientist
# 355     Data Scientist - TS/SCI FSP or CI Required
# 382                Applied AI Scientist / Engineer
# 405               Senior Machine Learning Engineer
# 412                                 Data Scientist
# 415                                 Data Scientist
# 435                                 Data Scientist
# 436              Data Scientist - Machine Learning
# 441                                 Data Scientist
# 486     Data Scientist - TS/SCI FSP or CI Required
# 507               Data Scientist - TS/SCI Required
# 511    Data Scientist(s)/Machine Learning Engineer
# 531                                 Data Scientist
# 584               Senior Machine Learning Engineer
# 603     Data Scientist - TS/SCI FSP or CI Required
# 636               Data Scientist - TS/SCI Required
# 640    Data Scientist(s)/Machine Learning Engineer
# 670                                 Data Scientist
#
#                     Salary Estimate  \
# index
# 32      $75K-$131K (Glassdoor est.)
# 43      $75K-$131K (Glassdoor est.)
# 113     $99K-$132K (Glassdoor est.)
# 118     $99K-$132K (Glassdoor est.)
# 130     $90K-$109K (Glassdoor est.)
# 144     $90K-$109K (Glassdoor est.)
# 193      $56K-$97K (Glassdoor est.)
# 209     $79K-$106K (Glassdoor est.)
# 212     $79K-$106K (Glassdoor est.)
# 227     $71K-$123K (Glassdoor est.)
# 244     $90K-$124K (Glassdoor est.)
# 258     $90K-$124K (Glassdoor est.)
# 269     $91K-$150K (Glassdoor est.)
# 274     $91K-$150K (Glassdoor est.)
# 281     $91K-$150K (Glassdoor est.)
# 284    $141K-$225K (Glassdoor est.)
# 308      $145K-$225K(Employer est.)
# 333     $79K-$147K (Glassdoor est.)
# 349    $122K-$146K (Glassdoor est.)
# 355    $122K-$146K (Glassdoor est.)
# 382    $112K-$116K (Glassdoor est.)
# 405    $110K-$163K (Glassdoor est.)
# 412    $124K-$198K (Glassdoor est.)
# 415    $124K-$198K (Glassdoor est.)
# 435     $79K-$133K (Glassdoor est.)
# 436     $79K-$133K (Glassdoor est.)
# 441     $79K-$133K (Glassdoor est.)
# 486      $31K-$56K (Glassdoor est.)
# 507     $95K-$119K (Glassdoor est.)
# 511    $212K-$331K (Glassdoor est.)
# 531     $66K-$112K (Glassdoor est.)
# 584    $138K-$158K (Glassdoor est.)
# 603     $80K-$132K (Glassdoor est.)
# 636     $92K-$155K (Glassdoor est.)
# 640     $92K-$155K (Glassdoor est.)
# 670    $105K-$167K (Glassdoor est.)
#
#                                          Job Description  Rating  \
# index
# 32     Cohere Health is simplifying healthcare for pa...     5.0
# 43     ArsenalBio’s mission is to develop efficacious...     5.0
# 113    At Phantom AI, experience the fast paced envir...     5.0
# 118    ArsenalBio’s mission is to develop efficacious...     5.0
# 130    Intro\n\nWhy this job?\n\n1. Work on a product...     5.0
# 144    Machine Learning Engineer\n\nUS Citizenship is...     5.0
# 193    Job Description\nClient JD below:\n\nWe need a...     5.0
# 209    US Citizenship Required and (TS/SCI with FSP o...     5.0
# 212    US Citizenship Required and (TS or TS/SCI) Req...     5.0
# 227    About The Position\n\nREE is redefining how mo...     5.0
# 244    Genesis Research is an international healthcar...     5.0
# 258    Full Time Data Scientist\n\nThe Drive Media is...     5.0
# 269    Paige is a software company helping pathologis...     5.0
# 274    Job Description\nClient JD below:\n\nWe need a...     5.0
# 281    This Jobot Job is hosted by: Scott Filbin\nAre...     5.0
# 284    Cohere Health is simplifying healthcare for pa...     5.0
# 308    Data Scientist\n\nRequirements\nMS or PhD in C...     5.0
# 333    Job Description\nData Scientist, Clearance Req...     5.0
# 349    We are the most sought after hedge fund in New...     5.0
# 355    US Citizenship Required and (TS/SCI with FSP o...     5.0
# 382    Applied AI Scientist Engineer New Iron is lead...     5.0
# 405    We are looking for an experienced engineer wit...     5.0
# 412    Job Description\nAre you an experienced Data S...     5.0
# 415    Title: Data Scientist\n\nLocation: Springfield...     5.0
# 435    Job Description\nWe are looking for the sharpe...     5.0
# 436    Data Scientist Machine Learning\n\n\nJob Descr...     5.0
# 441    Job Description\nWe are looking for a Data Sci...     5.0
# 486    US Citizenship Required and (TS/SCI with FSP o...     5.0
# 507    US Citizenship Required and (TS or TS/SCI) Req...     5.0
# 511    Company: AI/Data Science\nLocation: New York C...     5.0
# 531    Job Description\nData Scientist – Washington D...     5.0
# 584    We are looking for an experienced engineer wit...     5.0
# 603    US Citizenship Required and (TS/SCI with FSP o...     5.0
# 636    US Citizenship Required and (TS or TS/SCI) Req...     5.0
# 640    Company: AI/Data Science\nLocation: New York C...     5.0
# 670    100 Remote Opportunity As an AINLP Data Scient...     5.0
#
#                       Company Name                 Location  \
# index
# 32                   Cohere Health               Boston, MA
# 43             Arsenal Biosciences  South San Francisco, CA
# 113                     Phantom AI           Burlingame, CA
# 118            Arsenal Biosciences  South San Francisco, CA
# 130                    Notion Labs        San Francisco, CA
# 144    Expedition Technology, Inc.              Herndon, VA
# 193                     SkillSoniq        San Francisco, CA
# 209       Phoenix Operations Group   Annapolis Junction, MD
# 212       Phoenix Operations Group            Baltimore, MD
# 227                            REE            United States
# 244               Genesis Research              Hoboken, NJ
# 258          The Drive Media, Inc.             New York, NY
# 269                          Paige             New York, NY
# 274                     SkillSoniq        San Francisco, CA
# 281                          Jobot               Irvine, CA
# 284                  Cohere Health               Boston, MA
# 308                 Kollasoft Inc.             New York, NY
# 333                          SSATI               McLean, VA
# 349                        Averity             New York, NY
# 355       Phoenix Operations Group   Annapolis Junction, MD
# 382           New Iron Group, Inc.               Boston, MA
# 405                       LifeOmic              Raleigh, NC
# 412                       PROPRIUS            Sunnyvale, CA
# 415               Royce Geospatial          Springfield, VA
# 435                      PeopleCom               McLean, VA
# 436                 VANTA Partners            Open Fork, VA
# 441                         Maxiom              Ashburn, VA
# 486       Phoenix Operations Group   Annapolis Junction, MD
# 507       Phoenix Operations Group            Baltimore, MD
# 511     Blue Horizon Tek Solutions             New York, NY
# 531                   JCD Staffing           Washington, DC
# 584                       LifeOmic              Raleigh, NC
# 603       Phoenix Operations Group   Annapolis Junction, MD
# 636       Phoenix Operations Group            Baltimore, MD
# 640     Blue Horizon Tek Solutions             New York, NY
# 670           ChaTeck Incorporated        San Francisco, CA
#
#                   Headquarters                 Size  Founded  \
# index
# 32                  Boston, MA    1 to 50 employees   2019.0
# 43     South San Francisco, CA  51 to 200 employees   2019.0
# 113             Burlingame, CA    1 to 50 employees   2016.0
# 118    South San Francisco, CA  51 to 200 employees   2019.0
# 130          San Francisco, CA    1 to 50 employees   2016.0
# 144                 Dulles, VA    1 to 50 employees   2013.0
# 193            Jersey City, NJ              Unknown      NaN
# 209               Woodbine, MD    1 to 50 employees   2011.0
# 212               Woodbine, MD    1 to 50 employees   2011.0
# 227      Tel Aviv-Yafo, Israel  51 to 200 employees   2018.0
# 244                Hoboken, NJ    1 to 50 employees   2009.0
# 258                        NaN              Unknown      NaN
# 269               New York, NY    1 to 50 employees   2018.0
# 274            Jersey City, NJ              Unknown      NaN
# 281                 Irvine, CA  51 to 200 employees   2018.0
# 284                 Boston, MA    1 to 50 employees   2019.0
# 308                 Irving, TX              Unknown      NaN
# 333     Annapolis Junction, MD    1 to 50 employees   2003.0
# 349               New York, NY    1 to 50 employees   2014.0
# 355               Woodbine, MD    1 to 50 employees   2011.0
# 382                 Austin, TX    1 to 50 employees   2003.0
# 405           Indianapolis, IN  51 to 200 employees   2016.0
# 412     London, United Kingdom    1 to 50 employees      NaN
# 415              Arlington, VA  51 to 200 employees   2014.0
# 435                 Reston, VA    1 to 50 employees      NaN
# 436           Clifton Park, NY    1 to 50 employees   2018.0
# 441                Ashburn, VA    1 to 50 employees      NaN
# 486               Woodbine, MD    1 to 50 employees   2011.0
# 507               Woodbine, MD    1 to 50 employees   2011.0
# 511          Coconut Creek, FL    1 to 50 employees   1987.0
# 531             Germantown, MD    1 to 50 employees      NaN
# 584           Indianapolis, IN  51 to 200 employees   2016.0
# 603               Woodbine, MD    1 to 50 employees   2011.0
# 636               Woodbine, MD    1 to 50 employees   2011.0
# 640          Coconut Creek, FL    1 to 50 employees   1987.0
# 670            Santa Clara, CA    1 to 50 employees      NaN
#
#        Type of ownership                                 Industry  \
# index
# 32     Company - Private                              IT Services
# 43     Company - Private                Biotech & Pharmaceuticals
# 113    Company - Private             Computer Hardware & Software
# 118    Company - Private                Biotech & Pharmaceuticals
# 130    Company - Private  Enterprise Software & Network Solutions
# 144    Company - Private                      Aerospace & Defense
# 193     Company - Public                                      NaN
# 209    Company - Private                              IT Services
# 212    Company - Private                              IT Services
# 227    Company - Private   Transportation Equipment Manufacturing
# 244    Company - Private                Biotech & Pharmaceuticals
# 258              Unknown                                      NaN
# 269    Company - Private  Enterprise Software & Network Solutions
# 274     Company - Public                                      NaN
# 281    Company - Private                   Staffing & Outsourcing
# 284    Company - Private                              IT Services
# 308     Company - Public                                      NaN
# 333    Company - Private             Computer Hardware & Software
# 349    Company - Private                   Staffing & Outsourcing
# 355    Company - Private                              IT Services
# 382             Contract             Computer Hardware & Software
# 405    Company - Private  Enterprise Software & Network Solutions
# 412    Company - Private  Enterprise Software & Network Solutions
# 415    Company - Private                      Aerospace & Defense
# 435    Company - Private                                      NaN
# 436    Company - Private                   Staffing & Outsourcing
# 441     Company - Public                                      NaN
# 486    Company - Private                              IT Services
# 507    Company - Private                              IT Services
# 511    Company - Private                   Staffing & Outsourcing
# 531    Company - Private                                      NaN
# 584    Company - Private  Enterprise Software & Network Solutions
# 603    Company - Private                              IT Services
# 636    Company - Private                              IT Services
# 640    Company - Private                   Staffing & Outsourcing
# 670    Company - Private                  Advertising & Marketing
#
#                           Sector                   Revenue Competitors  \
# index
# 32        Information Technology  Unknown / Non-Applicable         NaN
# 43     Biotech & Pharmaceuticals  Unknown / Non-Applicable         NaN
# 113       Information Technology  Unknown / Non-Applicable         NaN
# 118    Biotech & Pharmaceuticals  Unknown / Non-Applicable         NaN
# 130       Information Technology  Unknown / Non-Applicable         NaN
# 144          Aerospace & Defense  $10 to $25 million (USD)         NaN
# 193                          NaN  Unknown / Non-Applicable         NaN
# 209       Information Technology    $1 to $5 million (USD)         NaN
# 212       Information Technology    $1 to $5 million (USD)         NaN
# 227                Manufacturing  Unknown / Non-Applicable         NaN
# 244    Biotech & Pharmaceuticals  Unknown / Non-Applicable         NaN
# 258                          NaN  Unknown / Non-Applicable         NaN
# 269       Information Technology  Unknown / Non-Applicable         NaN
# 274                          NaN  Unknown / Non-Applicable         NaN
# 281            Business Services  $25 to $50 million (USD)         NaN
# 284       Information Technology  Unknown / Non-Applicable         NaN
# 308                          NaN  Unknown / Non-Applicable         NaN
# 333       Information Technology  $10 to $25 million (USD)         NaN
# 349            Business Services  Unknown / Non-Applicable         NaN
# 355       Information Technology    $1 to $5 million (USD)         NaN
# 382       Information Technology  Unknown / Non-Applicable         NaN
# 405       Information Technology  Unknown / Non-Applicable         NaN
# 412       Information Technology  Unknown / Non-Applicable         NaN
# 415          Aerospace & Defense  $10 to $25 million (USD)         NaN
# 435                          NaN    $1 to $5 million (USD)         NaN
# 436            Business Services  Unknown / Non-Applicable         NaN
# 441                          NaN  Unknown / Non-Applicable         NaN
# 486       Information Technology    $1 to $5 million (USD)         NaN
# 507       Information Technology    $1 to $5 million (USD)         NaN
# 511            Business Services  Unknown / Non-Applicable         NaN
# 531                          NaN  Unknown / Non-Applicable         NaN
# 584       Information Technology  Unknown / Non-Applicable         NaN
# 603       Information Technology    $1 to $5 million (USD)         NaN
# 636       Information Technology    $1 to $5 million (USD)         NaN
# 640            Business Services  Unknown / Non-Applicable         NaN
# 670            Business Services    $1 to $5 million (USD)         NaN
#
#        Rating in name
# index
# 32                5.0
# 43                5.0
# 113               5.0
# 118               5.0
# 130               5.0
# 144               5.0
# 193               5.0
# 209               5.0
# 212               5.0
# 227               5.0
# 244               5.0
# 258               5.0
# 269               5.0
# 274               5.0
# 281               5.0
# 284               5.0
# 308               3.2
# 333               5.0
# 349               5.0
# 355               5.0
# 382               5.0
# 405               5.0
# 412               5.0
# 415               5.0
# 435               5.0
# 436               5.0
# 441               5.0
# 486               5.0
# 507               5.0
# 511               5.0
# 531               5.0
# 584               5.0
# 603               5.0
# 636               5.0
# 640               5.0
# 670               5.0

# %%
# For the third case, the company name is not available therefore it will be replaced with np.nan
# The observation with which this discrepancy has the most similarities and not conflicting data is the of 'The Drive Media, Inc.'
jobs.loc[(jobs['Rating']==5.0) & (jobs['Rating in name']==3.2),'Company Name']=np.nan

# %% [markdown]
# ### Suitable replacement for null values in the rating column

# %%
# Are there outliers?
print(jobs['Rating'].agg([np.mean,np.median]))
# Out:
# mean      3.88129
# median    3.80000
# Name: Rating, dtype: float64

# %%
# Since mean isn't so far away from median, there isn't much effect of outliers therefore null values in Rating will be ...
# filled with the median

jobs['Rating'].fillna(jobs['Rating'].mean(),inplace=True)

# %%
# Checking if no entry in rating column is out of range
jobs['Rating'].agg([min,max])
# Out:
# min    2.0
# max    5.0
# Name: Rating, dtype: float64

# %%
# deleting the 'Rating in name' column
del jobs['Rating in name']

# %% [markdown]
# ### Dealing with missing values in the Headquarters column

# %%
# Viewing the entries with missing headquarters
jobs[jobs['Headquarters'].isna()]['Company Name'].unique()
# Out:
# array(['Covid-19 Search Partners', 'Radical Convergence',
#        'The Drive Media, Inc.', 'Point72 Ventures', 'Hatch Data Inc',
#        'HireAi', 'Voice', 'Blue Cloak LLC', 'Sophinea',
#        'Monte Rosa Therapeutics', 'GrainBridge, LLC',
#        'Berico Technologies', 'Kehe Food Distributors', 'Pactera Edge',
#        'JKGT', 'AccessHope'], dtype=object)

# %%
# Are there other instances where the headquarters of these companies are mentioned?
for j in jobs[jobs['Headquarters'].isna()]['Company Name'].unique():
    if jobs[(jobs['Company Name']==j) &(jobs['Headquarters'].notna())]['Company Name'].count()>0:
        print(jobs[jobs['Company Name']==j])

# %% [markdown]
# ### There aren't any instances of where the headquarters of a company is missing in one observation and present in another

# %% [markdown]
# ### Dealing with missing values in the Size column

# %%
# Viewing the entries with missing sizes
jobs[jobs['Size'].isna()]['Company Name'].unique()
# Out:
# array(['Covid-19 Search Partners', 'Radical Convergence',
#        'Point72 Ventures', 'Hatch Data Inc', 'HireAi', 'Blue Cloak LLC',
#        'Monte Rosa Therapeutics', 'GrainBridge, LLC',
#        'Berico Technologies', 'Kehe Food Distributors', 'Pactera Edge',
#        'JKGT', 'AccessHope'], dtype=object)

# %%
for j in jobs[jobs['Size'].isna()]['Company Name'].unique():
    if jobs[(jobs['Company Name']==j) &(jobs['Size'].notna())]['Company Name'].count()>0:
        print(jobs[jobs['Company Name']==j])

# %% [markdown]
# ### There aren't any instances of where the Size of a company is missing in one observation and present in another

# %% [markdown]
# ### Dealing with missing values in the Founded column

# %%
# Viewing the entries with missing sizes
jobs[jobs['Founded'].isna()]['Company Name'].unique()
# Out:
# array(['CareDx', 'Maxar Technologies', 'Covid-19 Search Partners',
#        'Radical Convergence', 'SkillSoniq', 'Joby Aviation',
#        'Encode, Inc.', 'Surya Systems', 'Predictive Research Inc',
#        'Descript', 'Better Hire', 'The Drive Media, Inc.',
#        'Trovetechs Inc', 'PETADATA', 'Colony Brands', 'Capio Group',
#        'Kollasoft Inc.', nan, 'Advance Sourcing Concepts', 'Microagility',
#        'Conch Technologies, Inc', 'Rainmaker Resources, LLC', 'B4Corp',
#        'Solving IT International Inc', 'Stride Search', 'Shimento, Inc.',
#        'Point72 Ventures', 'Hatch Data Inc', 'SolutionIT, Inc.', 'HireAi',
#        'WCG (WIRB-Copernicus Group)', 'Navio', 'PROPRIUS',
#        'TECHNOCRAFT Solutions', 'Latitude, Inc.', 'Conflux Systems Inc.',
#        'Voice', 'Falcon IT & Staffing Solutions', 'DataLab USA',
#        'PeopleCom', 'Blue Icy Water, LLC', 'Sonde Health', 'Maxiom',
#        'Hackensack Meridian Health', 'Blue Cloak LLC', 'Numeric, LLC',
#        'Centraprise', 'Radiant Digital', 'IntelliPro Group Inc.',
#        'Lorven Technologies Inc', 'Tygart Technology, Inc',
#        'Two95 International Inc.', 'Sophinea', 'Sharpedge Solutions Inc',
#        'Alaka`ina Foundation Family of Companies',
#        'Monte Rosa Therapeutics', 'Comtech Global Inc', 'CompuForce',
#        'JCD Staffing', 'Xator Corporation', 'Temboo', 'Kibo',
#        'Applied Research Laboratories', 'Conagen',
#        'Homology Medicines, Inc.', 'Kognetics', 'IMG Systems',
#        'GrainBridge, LLC', 'Sprezzatura Management Consulting',
#        'Advanced Bio-Logic Solutions Corp',
#        'Central Business Solutions, Inc', 'Unicom Technologies INC',
#        'Berico Technologies', 'Kehe Food Distributors', 'Pactera Edge',
#        'Qurate Retail Group', 'Clear Ridge Defense', 'JKGT', 'AccessHope',
#        'ChaTeck Incorporated'], dtype=object)

# %%
for j in jobs[jobs['Founded'].isna()]['Company Name'].unique():
    if jobs[(jobs['Company Name']==j) &(jobs['Founded'].notna())]['Company Name'].count()>0:
        print(jobs[jobs['Company Name']==j])

# %% [markdown]
# ### There aren't any instances of where the Size of a company is missing in one observation and present in another

# %% [markdown]
# ### Repeating same for the other columns with missing values

# %%
for j in jobs[jobs['Type of ownership'].isna()]['Company Name'].unique():
    if jobs[(jobs['Company Name']==j) &(jobs['Type of ownership'].notna())]['Company Name'].count()>0:
        print(jobs[jobs['Company Name']==j])

# %%
for j in jobs[jobs['Industry'].isna()]['Company Name'].unique():
    if jobs[(jobs['Company Name']==j) &(jobs['Industry'].notna())]['Company Name'].count()>0:
        print(jobs[jobs['Company Name']==j])

# %%
for j in jobs[jobs['Revenue'].isna()]['Company Name'].unique():
    if jobs[(jobs['Company Name']==j) &(jobs['Revenue'].notna())]['Company Name'].count()>0:
        print(jobs[jobs['Company Name']==j])

# %%
for j in jobs[jobs['Competitors'].isna()]['Company Name'].unique():
    if jobs[(jobs['Company Name']==j) &(jobs['Competitors'].notna())]['Company Name'].count()>0:
        print(jobs[jobs['Company Name']==j])

# %%
for q in jobs[jobs['Competitors'].isna()]['Company Name'].unique():
    print(q)
# Out:
# ManTech
# Analysis Group
# HG Insights
# Novartis
# iRobot
# XSELL Technologies
# Old World Industries
# Mathematica Policy Research
# Guzman & Griffin Technologies (GGTI)
# Upside Business Travel
# Buckman
# Tower Health
# Triplebyte
# Exponent
# Spectrum Communications and Consulting
# Oversight Systems
# LSQ
# MIT Lincoln Laboratory
# Kingfisher Systems
# Formation
# Cohere Health
# Acuity Insurance
# Puget Sound Energy
# Sandhills Global
# Great-Circle Technologies
# Cambridge Associates, LLC
# Cenlar
# Arsenal Biosciences
# Eversight
# Pfizer
# Klaviyo
# Intellectual Ventures
# GovTech
# Quick Base
# Giving Assistant
# IT Concepts
# iSeatz
# Summa Health System
# Benson Hill
# Envision LLC
# Systems & Technology Research
# Bayview Asset Management
# Via Transportation
# Tempus Labs
# Autodesk
# Amyris
# Powertek
# The Mom Project
# Lightspeed Systems
# Comprehensive Healthcare
# Fullpower Technologies, Inc.
# Mars
# NuWave Solutions
# Merrick Bank
# QOMPLX
# Avlino
# Stratagem Group
# Evidation
# Tecolote Research
# Tivity Health
# hc1
# HP Inc.
# AllianceBernstein
# Big Huge Games
# Maxar Technologies
# Phantom AI
# Spring Health
# ClearEdge
# Scoop
# Montway Inc
# Juniper Networks
# Notion Labs
# Lendio
# Direct Agents
# NAVEX Global
# Upstart
# AppLovin
# ISO New England
# Relativity
# Tempo Automation
# Expedition Technology, Inc.
# Crown Bioscience
# GNS Healthcare
# OneMagnify
# SPECTRUM
# Advanced BioScience Laboratories
# Procore Technologies
# Ritedose
# Covid-19 Search Partners
# bioMérieux
# Radical Convergence
# Leidos
# Shelter Insurance
# USAC
# Offerpad
# Quartet Health
# Resurgent Capital Services
# Riverside Research Institute
# webfx.com
# Argo Group US
# BWX Technologies
# Life360
# MassMutual
# Genentech
# Sage Intacct
# Shape Security
# SkillSoniq
# Joby Aviation
# Rubius Therapeutics
# GreatAmerica Financial Services
# Coverent
# Rocket Lawyer
# Alion Science & Technology
# Protolabs
# Quest Integrity
# Phoenix Operations Group
# Central California Alliance for Health
# Security Finance Corporation of Spartanburg
# Opendoor
# Global Data Management Inc
# Photon Infotech
# REE
# T. Rowe Price
# Encode, Inc.
# Brighthouse Financial
# Surya Systems
# Predictive Research Inc
# 1010data
# Gigya
# Genesis Research
# Trace Data
# Descript
# Better Hire
# Insider Inc
# Rapid Value Solutions
# Battelle
# The Drive Media, Inc.
# US Pharmacopeia
# Itlize Global
# Paige
# Metronome, LLC
# FHLBank Pittsburgh
# Altus Group
# Jobot
# Trovetechs Inc
# Mackin
# PETADATA
# VBeyond Corporation
# Colony Brands
# Capio Group
# SleePare
# ShorePoint
# Dolphin
# TE Connectivity
# State of Virginia
# TA Digital
# Market America Inc
# TrueAccord
# ALTA IT Services
# Kollasoft Inc.
# nan
# ASRC Federal Holding Company
# Adwait Algorithm
# Cambridge FX
# Metromile
# Advance Sourcing Concepts
# Enterprise Solutions Inc
# Microagility
# Conch Technologies, Inc
# Rainmaker Resources, LLC
# 22nd Century Technologies
# Huxley
# B4Corp
# Blue Cross and Blue Shield of North Carolina
# Jane Street
# SSATI
# Solving IT International Inc
# Stride Search
# Software Engineering Institute
# TechProjects
# 7Park Data
# Ameritas Life Insurance Corp
# Shimento, Inc.
# Averity
# Point72 Ventures
# Cambridge Mobile Telematics
# Blend360
# Nolij Consulting
# Hatch Data Inc
# Compass Consulting Group
# SolutionIT, Inc.
# Perspecta
# Allen Institute
# Bayside Solutions
# Evolve Vacation Rental
# AgreeYa Solutions
# New Iron Group, Inc.
# Travelers
# Twitch
# Biogen
# HireAi
# WCG (WIRB-Copernicus Group)
# Dynetics
# Navy Federal Credit Union
# Exact Sciences Corporation
# Community Behavioral Health
# Reynolds American
# LifeOmic
# Visionist, Inc.
# Navio
# Concerto HealthAI
# Evolvinc
# PROPRIUS
# TECHNOCRAFT Solutions
# Latitude, Inc.
# Royce Geospatial
# CyberCoders
# InvenTech Info
# Conflux Systems Inc.
# Voice
# Falcon IT & Staffing Solutions
# Werner Enterprises Inc
# PeopleCom
# VANTA Partners
# Blue Icy Water, LLC
# Farmer's Business Network, Inc.
# Sonde Health
# Maxiom
# Change Healthcare
# DCS Corp
# Hive (CA)
# Hackensack Meridian Health
# Net2Source Inc.
# The Trade Desk
# MoTek Technologies
# HPOne
# Blue Cloak LLC
# TBWA\Chiat\Day
# ThreeBridge Solutions
# Numeric, LLC
# Centraprise
# DW Simpson
# LinQuest
# Trexquant Investment
# Fleetcor
# Radiant Digital
# Child Care Aware of America
# IntelliPro Group Inc.
# USI
# Pragmatics, Inc.
# Crossover Health
# Lorven Technologies Inc
# Tygart Technology, Inc
# Murray Resources
# New York Technology Partners
# Two95 International Inc.
# Sophinea
# CRS Group
# Blackstone Talent Group
# Blue Horizon Tek Solutions
# Sharpedge Solutions Inc
# Alaka`ina Foundation Family of Companies
# Hexagon US Federal
# Monte Rosa Therapeutics
# Comtech Global Inc
# Aveshka, Inc.
# 10x Genomics
# CompuForce
# 1-800-Flowers
# Aptive
# JCD Staffing
# Thumbtack
# MILVETS Systems Technology, Inc.
# Kforce
# OppLoans
# Brillient
# Xator Corporation
# HAN IT Staffing Inc.
# Infinitive Inc
# E3 Federal Solutions
# Peraton
# Group O
# CaptiveAire
# Temboo
# Kibo
# Applied Research Laboratories
# Conagen
# Alector
# Homology Medicines, Inc.
# Inland Empire Health Plan
# CIA
# Maven Wave Partners
# Ovative Group
# Kognetics
# Envision Healthcare
# ConsumerTrack
# Meridian Knowledge Solutions
# IMG Systems
# Trident Systems Inc
# GrainBridge, LLC
# Sprezzatura Management Consulting
# Progress Rail, A Caterpillar Company
# Axiologic Solutions
# Indigo Slate
# Advanced Bio-Logic Solutions Corp
# Alignment Healthcare
# WGSN
# ISYS Technologies, Inc.
# TransVoyant
# Geotab
# EGlobalTech
# Central Business Solutions, Inc
# Unicom Technologies INC
# Americo Life
# Berico Technologies
# Kehe Food Distributors
# Pactera Edge
# Qurate Retail Group
# A-Line Staffing Solutions
# Clear Ridge Defense
# Criterion Systems, Inc.
# TRANZACT
# JKGT
# AccessHope
# ChaTeck Incorporated

# %% [markdown]
# ### Alternative ways for filling in missing values in the Competitors column

# %%
jobs['Competitors']
# Out:
# index
# 0                EmblemHealth, UnitedHealth Group, Aetna
# 1                                                    NaN
# 2                                                    NaN
# 3      MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4                   Commerce Signals, Cardlytics, Yodlee
#                              ...
# 667                                                  NaN
# 668                                                  NaN
# 669                                                  NaN
# 670                                                  NaN
# 671                                                  NaN
# Name: Competitors, Length: 659, dtype: object

# %%
jobs['Competitors'].isnull().sum()
# Out:
# 488

# %% [markdown]
# ### 488 missing values in Competitors column

# %%
# Filling in missing entries with missing values in competitors column
# By making use of instances where the company name has been mentioned as a competitor in a different entry
for q in jobs[jobs['Competitors'].isna()]['Company Name'].unique():
    qval=[]
    qval.append(jobs[jobs['Competitors'].str.contains(q,na=False,regex=False)]['Company Name'].unique())
    newval=''.join(map(str,qval)).strip('[]')
    if len(newval)>0:
        jobs.loc[jobs['Company Name']==q,'Competitors']=newval

# %%
jobs['Competitors'].isnull().sum()
# Out:
# 469

# %% [markdown]
# ### 19 missing values for competitors filled

# %% [markdown]
# ### Working on the Job Title

# %%
# checking the various representation of seniority in the the job title by visualising the unique representations of job title
jobs['Job Title'].unique()
# Out:
# array(['Sr Data Scientist', 'Data Scientist',
#        'Data Scientist / Machine Learning Expert',
#        'Staff Data Scientist - Analytics',
#        'Data Scientist - Statistics, Early Career', 'Data Modeler',
#        'Experienced Data Scientist', 'Data Scientist - Contract',
#        'Data Analyst II', 'Medical Lab Scientist',
#        'Data Scientist/Machine Learning', 'Human Factors Scientist',
#        'Business Intelligence Analyst I- Data Insights',
#        'Data Scientist - Risk', 'Data Scientist-Human Resources',
#        'Senior Research Statistician- Data Scientist', 'Data Engineer',
#        'Associate Data Scientist', 'Business Intelligence Analyst',
#        'Senior Analyst/Data Scientist', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst I',
#        'Scientist - Molecular Biology',
#        'Computational Scientist, Machine Learning',
#        'Senior Data Scientist', 'Jr. Data Engineer',
#        'E-Commerce Data Analyst', 'Data Analytics Engineer',
#        'Product Data Scientist - Ads Data Science',
#        'Data Scientist - Intermediate', 'Global Data Analyst',
#        'Data & Machine Learning Scientist',
#        'Data Scientist - Machine Learning', 'Data Engineer (Remote)',
#        'Data Scientist, Applied Machine Learning - Bay Area',
#        'Principal Data Scientist', 'Business Data Analyst',
#        'Purification Scientist', 'Data Engineer, Enterprise Analytics',
#        'Data Scientist 3 (718)', 'Real World Science, Data Scientist',
#        'Data Scientist - Image and Video Analytics',
#        'Data Science Manager, Payment Acceptance - USA',
#        'Data Scientist / Applied Mathematician',
#        'Patient Safety- Associate Data Scientist',
#        '(Sr.) Data Scientist -', 'Data Scientist, Kinship - NYC/Portland',
#        'Applied Technology Researcher / Data Scientist',
#        'Health Data Scientist - Biomedical/Biostats',
#        'Staff Data Scientist', 'Sr Data Engineer (Sr BI Developer)',
#        'Lead Data Scientist', 'RFP Data Analyst',
#        'Data Scientist (TS/SCI)', 'Software Engineer - Data Science',
#        'Data Analyst/Engineer', 'NGS Scientist', 'Senior Data Engineer',
#        'Sr. ML/Data Scientist - AI/NLP/Chatbot',
#        'Data Integration and Modeling Engineer',
#        'Tableau Data Engineer 20-0117', 'AI Data Scientist',
#        'Research Scientist Patient Preferences (Remote)',
#        'Scientist - Biomarker and Flow Cytometry', 'Analytics Manager',
#        'Staff Scientist- Upstream PD',
#        'Sr Scientist - Extractables & Leachables',
#        'ELISA RESEARCH SCIENTIST (CV-15)', 'Say Business Data Analyst',
#        'Geospatial Data Scientist', 'Computational Scientist',
#        'Senior Data Analyst', 'Sr Data Analyst',
#        'Machine Learning Scientist - Bay Area, CA',
#        'Senior Data Scientist - Algorithms',
#        'Senior Data & Machine Learning Scientist',
#        'Research Scientist - Patient-Centered Research (Remote)',
#        'Jr. Business Data Analyst (position added 6/12/2020)',
#        'Sr. Data Scientist II',
#        'Production Engineer - Statistics/Data Analysis',
#        'Statistical Scientist', 'Computational Behavioral Scientist',
#        'Principal Data Scientist - Machine Learning',
#        'Principal Machine Learning Scientist',
#        'Senior Data Scientist - R&D Oncology',
#        'Health Plan Data Analyst, Sr',
#        'Principal Scientist/Associate Director, Quality Control and Analytical Technologies',
#        'Analytics - Business Assurance Data Analyst',
#        'Senior Data Scientist – Image Analytics, Novartis AI Innovation Lab',
#        'Data Science Instructor', 'Senior Business Intelligence Analyst',
#        'In-Line Inspection Data Analyst',
#        'Data Scientist - TS/SCI FSP or CI Required',
#        'Data Scientist - TS/SCI Required',
#        'Data Science Software Engineer',
#        'ENGINEER - COMPUTER SCIENTIST - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING - SAN ANTONIO OR',
#        'AI Ops Data Scientist', 'Intelligence Data Analyst, Senior',
#        'Analytics Manager - Data Mart',
#        'Data Modeler (Analytical Systems)',
#        'Senior Machine Learning Scientist - Bay Area, CA',
#        'Report Writer-Data Analyst', 'Staff Data Scientist - Pricing',
#        'Equity Data Insights Analyst - Quantitative Analyst',
#        'Operations Data Analyst', 'Software Data Engineer',
#        'Real World Evidence (RWE) Scientist', 'Computer Scientist 1',
#        'Environmental Data Science', 'Staff BI and Data Engineer',
#        'Data Scientist - Statistics, Mid-Career',
#        'Director of Data Science',
#        'Data Engineer, Digital & Comp Pathology',
#        'Manager / Lead, Data Science & Analytics',
#        'Diversity and Inclusion Data Analyst',
#        'Data Scientist Machine Learning', 'Chief Scientist',
#        'Development Scientist, Voltaren',
#        'Principal Data & Analytics Platform Engineer',
#        'Machine Learning Engineer/Scientist',
#        'Data Analyst - Unilever Prestige', 'VP, Data Science',
#        'Data Engineer - Kafka', 'Decision Scientist',
#        'Data Science All Star Program - Data Engineer Track',
#        'Scientist - Machine Learning', 'Sr. Data Scientist',
#        'Applied AI Scientist / Engineer',
#        'Data Engineer (Analytics, SQL, Python, AWS)',
#        'Senior Data Analyst - Finance & Platform Analytics',
#        'Market Research Data Scientist',
#        'IT Partner Digital Health Technology and Data Science',
#        'Software Engineer (Data Scientist, C,C++,Linux,Unix) - SISW - MG',
#        'Senior Clinical Data Scientist Programmer',
#        'Computer Vision / Deep Learning Scientist',
#        'Data Solutions Engineer - Data Modeler',
#        'Data Scientist (TS/SCI w/ Poly)',
#        'Weapons and Sensors Engineer/Scientist',
#        'Applied Computer Scientist', 'Cloud Data Engineer (Azure)',
#        'Lead Certified Clinical Laboratory Scientist - Saturday - Tuesday, 8:00pm - 6:30am shift',
#        'Sr. Data Analyst',
#        'Senior Scientist - Toxicologist - Product Integrity (Stewardship)',
#        'Senior Machine Learning Engineer',
#        'Data Scientist- Industrial Discrete Sector Industry',
#        'Senior Principal Data Scientist (Python/R)',
#        'Data Scientist(s)/Machine Learning Engineer',
#        'Scientist / Group Lead, Cancer Biology',
#        'Manager, Field Application Scientist, Southeast',
#        'COMPUTER SCIENTIST - ENGINEER - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING',
#        'Machine Learning Scientist / Engineer', 'Data Science Analyst',
#        'COMPUTER SCIENTIST - ENGINEER - RESEARCH COMPUTER SCIENTIST - TRANSPORTATION TECHNOLOGY',
#        'Software Engineer - Machine Learning & Data Science (Applied Intelligence Services Team)',
#        'Clinical Data Analyst', 'Data Scientist Technical Specialist',
#        'Data Science Manager', 'Big Data Engineer', 'Data Architect',
#        'Aviation AI/ML Data Scientist', 'Machine Learning Engineer, Sr.',
#        'Information Systems Engineering Specialist (Engineering Scientist)',
#        'Scientist/Research Associate-Metabolic Engineering',
#        'Vice President, Biometrics and Clinical Data Management',
#        'Enterprise Data Analyst (Enterprise Portfolio Management Office)',
#        'Lead Data Scientist – Network Analysis and Control',
#        'Sr. Research Associate/ Scientist, NGS prep & Molecular Genomics',
#        'Developer III - Data Science',
#        'Hydrogen/Tritium Materials Scientist (Experienced)',
#        'Data Scientist/Data Analytics Practitioner',
#        'AI/ML - Machine Learning Scientist, Siri Understanding'],
#       dtype=object)

# %%
# Creating a seniority column
jobs['Seniority']=jobs['Job Title'].str.contains('Sr.|Senior|Sr')

# %%
# Checking visually if there's any title with a seniority requirement that was missed
jobs[~jobs['Seniority']]['Job Title'].unique()
# Out:
# array(['Data Scientist', 'Data Scientist / Machine Learning Expert',
#        'Staff Data Scientist - Analytics',
#        'Data Scientist - Statistics, Early Career', 'Data Modeler',
#        'Experienced Data Scientist', 'Data Scientist - Contract',
#        'Data Analyst II', 'Medical Lab Scientist',
#        'Data Scientist/Machine Learning', 'Human Factors Scientist',
#        'Business Intelligence Analyst I- Data Insights',
#        'Data Scientist - Risk', 'Data Scientist-Human Resources',
#        'Data Engineer', 'Associate Data Scientist',
#        'Business Intelligence Analyst', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst I',
#        'Scientist - Molecular Biology',
#        'Computational Scientist, Machine Learning', 'Jr. Data Engineer',
#        'E-Commerce Data Analyst', 'Data Analytics Engineer',
#        'Product Data Scientist - Ads Data Science',
#        'Data Scientist - Intermediate', 'Global Data Analyst',
#        'Data & Machine Learning Scientist',
#        'Data Scientist - Machine Learning', 'Data Engineer (Remote)',
#        'Data Scientist, Applied Machine Learning - Bay Area',
#        'Principal Data Scientist', 'Business Data Analyst',
#        'Purification Scientist', 'Data Engineer, Enterprise Analytics',
#        'Data Scientist 3 (718)', 'Real World Science, Data Scientist',
#        'Data Scientist - Image and Video Analytics',
#        'Data Science Manager, Payment Acceptance - USA',
#        'Data Scientist / Applied Mathematician',
#        'Patient Safety- Associate Data Scientist',
#        'Data Scientist, Kinship - NYC/Portland',
#        'Applied Technology Researcher / Data Scientist',
#        'Health Data Scientist - Biomedical/Biostats',
#        'Staff Data Scientist', 'Lead Data Scientist', 'RFP Data Analyst',
#        'Data Scientist (TS/SCI)', 'Software Engineer - Data Science',
#        'Data Analyst/Engineer', 'NGS Scientist',
#        'Data Integration and Modeling Engineer',
#        'Tableau Data Engineer 20-0117', 'AI Data Scientist',
#        'Research Scientist Patient Preferences (Remote)',
#        'Scientist - Biomarker and Flow Cytometry', 'Analytics Manager',
#        'Staff Scientist- Upstream PD', 'ELISA RESEARCH SCIENTIST (CV-15)',
#        'Say Business Data Analyst', 'Geospatial Data Scientist',
#        'Computational Scientist',
#        'Machine Learning Scientist - Bay Area, CA',
#        'Research Scientist - Patient-Centered Research (Remote)',
#        'Jr. Business Data Analyst (position added 6/12/2020)',
#        'Production Engineer - Statistics/Data Analysis',
#        'Statistical Scientist', 'Computational Behavioral Scientist',
#        'Principal Data Scientist - Machine Learning',
#        'Principal Machine Learning Scientist',
#        'Principal Scientist/Associate Director, Quality Control and Analytical Technologies',
#        'Analytics - Business Assurance Data Analyst',
#        'Data Science Instructor', 'In-Line Inspection Data Analyst',
#        'Data Scientist - TS/SCI FSP or CI Required',
#        'Data Scientist - TS/SCI Required',
#        'Data Science Software Engineer',
#        'ENGINEER - COMPUTER SCIENTIST - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING - SAN ANTONIO OR',
#        'AI Ops Data Scientist', 'Analytics Manager - Data Mart',
#        'Data Modeler (Analytical Systems)', 'Report Writer-Data Analyst',
#        'Staff Data Scientist - Pricing',
#        'Equity Data Insights Analyst - Quantitative Analyst',
#        'Operations Data Analyst', 'Software Data Engineer',
#        'Real World Evidence (RWE) Scientist', 'Computer Scientist 1',
#        'Environmental Data Science', 'Staff BI and Data Engineer',
#        'Data Scientist - Statistics, Mid-Career',
#        'Director of Data Science',
#        'Data Engineer, Digital & Comp Pathology',
#        'Manager / Lead, Data Science & Analytics',
#        'Diversity and Inclusion Data Analyst',
#        'Data Scientist Machine Learning', 'Chief Scientist',
#        'Development Scientist, Voltaren',
#        'Principal Data & Analytics Platform Engineer',
#        'Machine Learning Engineer/Scientist',
#        'Data Analyst - Unilever Prestige', 'VP, Data Science',
#        'Data Engineer - Kafka', 'Decision Scientist',
#        'Data Science All Star Program - Data Engineer Track',
#        'Scientist - Machine Learning', 'Applied AI Scientist / Engineer',
#        'Data Engineer (Analytics, SQL, Python, AWS)',
#        'Market Research Data Scientist',
#        'IT Partner Digital Health Technology and Data Science',
#        'Software Engineer (Data Scientist, C,C++,Linux,Unix) - SISW - MG',
#        'Computer Vision / Deep Learning Scientist',
#        'Data Solutions Engineer - Data Modeler',
#        'Data Scientist (TS/SCI w/ Poly)',
#        'Weapons and Sensors Engineer/Scientist',
#        'Applied Computer Scientist', 'Cloud Data Engineer (Azure)',
#        'Lead Certified Clinical Laboratory Scientist - Saturday - Tuesday, 8:00pm - 6:30am shift',
#        'Data Scientist- Industrial Discrete Sector Industry',
#        'Data Scientist(s)/Machine Learning Engineer',
#        'Scientist / Group Lead, Cancer Biology',
#        'Manager, Field Application Scientist, Southeast',
#        'COMPUTER SCIENTIST - ENGINEER - RESEARCH COMPUTER SCIENTIST - SIGNAL PROCESSING',
#        'Machine Learning Scientist / Engineer', 'Data Science Analyst',
#        'COMPUTER SCIENTIST - ENGINEER - RESEARCH COMPUTER SCIENTIST - TRANSPORTATION TECHNOLOGY',
#        'Software Engineer - Machine Learning & Data Science (Applied Intelligence Services Team)',
#        'Clinical Data Analyst', 'Data Scientist Technical Specialist',
#        'Data Science Manager', 'Big Data Engineer', 'Data Architect',
#        'Aviation AI/ML Data Scientist',
#        'Information Systems Engineering Specialist (Engineering Scientist)',
#        'Scientist/Research Associate-Metabolic Engineering',
#        'Vice President, Biometrics and Clinical Data Management',
#        'Enterprise Data Analyst (Enterprise Portfolio Management Office)',
#        'Lead Data Scientist – Network Analysis and Control',
#        'Developer III - Data Science',
#        'Hydrogen/Tritium Materials Scientist (Experienced)',
#        'Data Scientist/Data Analytics Practitioner',
#        'AI/ML - Machine Learning Scientist, Siri Understanding'],
#       dtype=object)

# %% [markdown]
# ### Working on Salary Estimate

# %%
# Splitting the salary estimate column into Salary Estimate and the source of salary estimate
jobs[['Salary Estimate','Salary Source']]=jobs['Salary Estimate'].str.split('(',expand=True)

# Cleaning the unwanted ')' off the Salary Source column
jobs['Salary Source']=jobs['Salary Source'].str.strip(')')

jobs['Salary Estimate'].unique()
# Out:
# array(['$137K-$171K ', '$75K-$131K ', '$79K-$131K ', '$99K-$132K ',
#        '$90K-$109K ', '$101K-$165K ', '$56K-$97K ', '$79K-$106K ',
#        '$71K-$123K ', '$90K-$124K ', '$91K-$150K ', '$141K-$225K ',
#        '$145K-$225K', '$79K-$147K ', '$122K-$146K ', '$112K-$116K ',
#        '$110K-$163K ', '$124K-$198K ', '$79K-$133K ', '$69K-$116K ',
#        '$31K-$56K ', '$95K-$119K ', '$212K-$331K ', '$66K-$112K ',
#        '$128K-$201K ', '$138K-$158K ', '$80K-$132K ', '$87K-$141K ',
#        '$92K-$155K ', '$105K-$167K '], dtype=object)

# %%
jobs.head()
# Out:
#                Job Title Salary Estimate  \
# index
# 0      Sr Data Scientist    $137K-$171K
# 1         Data Scientist    $137K-$171K
# 2         Data Scientist    $137K-$171K
# 3         Data Scientist    $137K-$171K
# 4         Data Scientist    $137K-$171K
#
#                                          Job Description  Rating  \
# index
# 0      Description\n\nThe Senior Data Scientist is re...     3.1
# 1      Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2      Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3      JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4      Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#              Company Name       Location            Headquarters  \
# index
# 0             Healthfirst   New York, NY            New York, NY
# 1                 ManTech  Chantilly, VA             Herndon, VA
# 2          Analysis Group     Boston, MA              Boston, MA
# 3                 INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions   New York, NY            New York, NY
#
#                           Size  Founded        Type of ownership  \
# index
# 0       1001 to 5000 employees   1993.0   Nonprofit Organization
# 1      5001 to 10000 employees   1968.0         Company - Public
# 2       1001 to 5000 employees   1981.0  Private Practice / Firm
# 3        501 to 1000 employees   2000.0         Company - Public
# 4          51 to 200 employees   1998.0        Company - Private
#
#                                     Industry             Sector  \
# index
# 0                         Insurance Carriers          Insurance
# 1                     Research & Development  Business Services
# 2                                 Consulting  Business Services
# 3      Electrical & Electronic Manufacturing      Manufacturing
# 4                    Advertising & Marketing  Business Services
#
#                           Revenue  \
# index
# 0        Unknown / Non-Applicable
# 1          $1 to $2 billion (USD)
# 2      $100 to $500 million (USD)
# 3      $100 to $500 million (USD)
# 4        Unknown / Non-Applicable
#
#                                              Competitors  Seniority  \
# index
# 0                EmblemHealth, UnitedHealth Group, Aetna       True
# 1               'The Buffalo Group' 'CACI International'      False
# 2                                                    NaN      False
# 3      MKS Instruments, Pfeiffer Vacuum, Agilent Tech...      False
# 4                   Commerce Signals, Cardlytics, Yodlee      False
#
#         Salary Source
# index
# 0      Glassdoor est.
# 1      Glassdoor est.
# 2      Glassdoor est.
# 3      Glassdoor est.
# 4      Glassdoor est.

# %%
#changing category of of Glassdoor Salary Estimate
jobs['Salary Estimate'].astype('category')
# Out:
# index
# 0      $137K-$171K
# 1      $137K-$171K
# 2      $137K-$171K
# 3      $137K-$171K
# 4      $137K-$171K
#            ...
# 667    $105K-$167K
# 668    $105K-$167K
# 669    $105K-$167K
# 670    $105K-$167K
# 671    $105K-$167K
# Name: Salary Estimate, Length: 659, dtype: category
# Categories (30, object): ['$101K-$165K ', '$105K-$167K ', '$110K-$163K ', '$112K-$116K ', ..., '$91K-$150K ', '$92K-$155K ', '$95K-$119K ', '$99K-$132K ']

# %%
# splitting salary estimate column into minimum and maximum salary
jobs[['min salary','max salary']]=jobs['Salary Estimate'].str.split('-',expand=True)

#converting the min and max salary to integers
jobs['min salary']=jobs['min salary'].str.replace('$','').str.replace('K','').astype('int')
jobs['max salary']=jobs['max salary'].str.replace('$','').str.replace('K','').astype('int')
# Out:
# C:\Users\Isaac Femi\AppData\Local\Temp\ipykernel_11988\302702551.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   jobs['min salary']=jobs['min salary'].str.replace('$','').str.replace('K','').astype('int')
# C:\Users\Isaac Femi\AppData\Local\Temp\ipykernel_11988\302702551.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   jobs['max salary']=jobs['max salary'].str.replace('$','').str.replace('K','').astype('int')

# %%
# creating the average salary column
jobs['average salary']=(jobs['min salary']+jobs['max salary'])/2

# %%
# adding the dollar sign and K to the average salary, minimum salary and maximum salary
columns_to_edit=['average salary','min salary','max salary']
for i in columns_to_edit:
    jobs[i]='$'+ jobs[i].astype('str') + 'K'

# %%
#viewing the changes
jobs.head()
# Out:
#                Job Title Salary Estimate  \
# index
# 0      Sr Data Scientist    $137K-$171K
# 1         Data Scientist    $137K-$171K
# 2         Data Scientist    $137K-$171K
# 3         Data Scientist    $137K-$171K
# 4         Data Scientist    $137K-$171K
#
#                                          Job Description  Rating  \
# index
# 0      Description\n\nThe Senior Data Scientist is re...     3.1
# 1      Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2      Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3      JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4      Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#              Company Name       Location            Headquarters  \
# index
# 0             Healthfirst   New York, NY            New York, NY
# 1                 ManTech  Chantilly, VA             Herndon, VA
# 2          Analysis Group     Boston, MA              Boston, MA
# 3                 INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4      Affinity Solutions   New York, NY            New York, NY
#
#                           Size  Founded        Type of ownership  \
# index
# 0       1001 to 5000 employees   1993.0   Nonprofit Organization
# 1      5001 to 10000 employees   1968.0         Company - Public
# 2       1001 to 5000 employees   1981.0  Private Practice / Firm
# 3        501 to 1000 employees   2000.0         Company - Public
# 4          51 to 200 employees   1998.0        Company - Private
#
#                                     Industry             Sector  \
# index
# 0                         Insurance Carriers          Insurance
# 1                     Research & Development  Business Services
# 2                                 Consulting  Business Services
# 3      Electrical & Electronic Manufacturing      Manufacturing
# 4                    Advertising & Marketing  Business Services
#
#                           Revenue  \
# index
# 0        Unknown / Non-Applicable
# 1          $1 to $2 billion (USD)
# 2      $100 to $500 million (USD)
# 3      $100 to $500 million (USD)
# 4        Unknown / Non-Applicable
#
#                                              Competitors  Seniority  \
# index
# 0                EmblemHealth, UnitedHealth Group, Aetna       True
# 1               'The Buffalo Group' 'CACI International'      False
# 2                                                    NaN      False
# 3      MKS Instruments, Pfeiffer Vacuum, Agilent Tech...      False
# 4                   Commerce Signals, Cardlytics, Yodlee      False
#
#         Salary Source min salary max salary average salary
# index
# 0      Glassdoor est.      $137K      $171K        $154.0K
# 1      Glassdoor est.      $137K      $171K        $154.0K
# 2      Glassdoor est.      $137K      $171K        $154.0K
# 3      Glassdoor est.      $137K      $171K        $154.0K
# 4      Glassdoor est.      $137K      $171K        $154.0K

# %% [markdown]
# ### Working on Job description Column

# %%
# removing the unwanted values in the column
jobs['Job Description']=jobs['Job Description'].str.replace('\n',' ')

# %% [markdown]
# ### Working on Founded Column

# %%
# Converting the founded column to datetime
jobs['Founded']=pd.to_datetime(jobs['Founded'],format='%Y',errors='coerce').dt.strftime('%Y')

# %%
# Creating a company age column
jobs['Company Age']=int(dt.date.today().year)-jobs['Founded'].astype('float')

# %%
jobs
# Out:
#                Job Title Salary Estimate  \
# index
# 0      Sr Data Scientist    $137K-$171K
# 1         Data Scientist    $137K-$171K
# 2         Data Scientist    $137K-$171K
# 3         Data Scientist    $137K-$171K
# 4         Data Scientist    $137K-$171K
# ...                  ...             ...
# 667       Data Scientist    $105K-$167K
# 668       Data Scientist    $105K-$167K
# 669       Data Scientist    $105K-$167K
# 670       Data Scientist    $105K-$167K
# 671       Data Scientist    $105K-$167K
#
#                                          Job Description   Rating  \
# index
# 0      Description  The Senior Data Scientist is resp...  3.10000
# 1      Secure our Nation, Ignite your Future  Join th...  4.20000
# 2      Overview   Analysis Group is one of the larges...  3.80000
# 3      JOB DESCRIPTION:  Do you have a passion for Da...  3.50000
# 4      Data Scientist Affinity Solutions / Marketing ...  2.90000
# ...                                                  ...      ...
# 667    Summary  We’re looking for a data scientist to...  3.60000
# 668    Job Description Become a thought leader within...  3.88129
# 669    Join a thriving company that is changing the w...  3.88129
# 670    100 Remote Opportunity As an AINLP Data Scient...  5.00000
# 671    Description  The Data Scientist will be part o...  2.70000
#
#                Company Name           Location            Headquarters  \
# index
# 0               Healthfirst       New York, NY            New York, NY
# 1                   ManTech      Chantilly, VA             Herndon, VA
# 2            Analysis Group         Boston, MA              Boston, MA
# 3                   INFICON         Newton, MA  Bad Ragaz, Switzerland
# 4        Affinity Solutions       New York, NY            New York, NY
# ...                     ...                ...                     ...
# 667                TRANZACT       Fort Lee, NJ            Fort Lee, NJ
# 668                    JKGT  San Francisco, CA                     NaN
# 669              AccessHope      Irwindale, CA                     NaN
# 670    ChaTeck Incorporated  San Francisco, CA         Santa Clara, CA
# 671           1-800-Flowers       New York, NY         Carle Place, NY
#
#                           Size Founded        Type of ownership  \
# index
# 0       1001 to 5000 employees    1993   Nonprofit Organization
# 1      5001 to 10000 employees    1968         Company - Public
# 2       1001 to 5000 employees    1981  Private Practice / Firm
# 3        501 to 1000 employees    2000         Company - Public
# 4          51 to 200 employees    1998        Company - Private
# ...                        ...     ...                      ...
# 667     1001 to 5000 employees    1989        Company - Private
# 668                        NaN     NaN                      NaN
# 669                        NaN     NaN                      NaN
# 670          1 to 50 employees     NaN        Company - Private
# 671     1001 to 5000 employees    1976         Company - Public
#
#                                     Industry             Sector  \
# index
# 0                         Insurance Carriers          Insurance
# 1                     Research & Development  Business Services
# 2                                 Consulting  Business Services
# 3      Electrical & Electronic Manufacturing      Manufacturing
# 4                    Advertising & Marketing  Business Services
# ...                                      ...                ...
# 667                  Advertising & Marketing  Business Services
# 668                                      NaN                NaN
# 669                                      NaN                NaN
# 670                  Advertising & Marketing  Business Services
# 671                                Wholesale  Business Services
#
#                           Revenue  \
# index
# 0        Unknown / Non-Applicable
# 1          $1 to $2 billion (USD)
# 2      $100 to $500 million (USD)
# 3      $100 to $500 million (USD)
# 4        Unknown / Non-Applicable
# ...                           ...
# 667      Unknown / Non-Applicable
# 668                           NaN
# 669                           NaN
# 670        $1 to $5 million (USD)
# 671        $1 to $2 billion (USD)
#
#                                              Competitors  Seniority  \
# index
# 0                EmblemHealth, UnitedHealth Group, Aetna       True
# 1               'The Buffalo Group' 'CACI International'      False
# 2                                                    NaN      False
# 3      MKS Instruments, Pfeiffer Vacuum, Agilent Tech...      False
# 4                   Commerce Signals, Cardlytics, Yodlee      False
# ...                                                  ...        ...
# 667                                                  NaN      False
# 668                                                  NaN      False
# 669                                                  NaN      False
# 670                                                  NaN      False
# 671                                                  NaN      False
#
#         Salary Source min salary max salary average salary  Company Age
# index
# 0      Glassdoor est.      $137K      $171K        $154.0K         29.0
# 1      Glassdoor est.      $137K      $171K        $154.0K         54.0
# 2      Glassdoor est.      $137K      $171K        $154.0K         41.0
# 3      Glassdoor est.      $137K      $171K        $154.0K         22.0
# 4      Glassdoor est.      $137K      $171K        $154.0K         24.0
# ...               ...        ...        ...            ...          ...
# 667    Glassdoor est.      $105K      $167K        $136.0K         33.0
# 668    Glassdoor est.      $105K      $167K        $136.0K          NaN
# 669    Glassdoor est.      $105K      $167K        $136.0K          NaN
# 670    Glassdoor est.      $105K      $167K        $136.0K          NaN
# 671    Glassdoor est.      $105K      $167K        $136.0K         46.0
#
# [659 rows x 20 columns]

# %%
companyages=jobs['Company Age'].unique()
print(jobs['Company Age'].max(),jobs['Company Age'].min())
# Out:
# 241.0 3.0

# %%
jobs.dtypes
# Out:
# Job Title             object
# Salary Estimate       object
# Job Description       object
# Rating               float64
# Company Name          object
# Location              object
# Headquarters          object
# Size                  object
# Founded               object
# Type of ownership     object
# Industry              object
# Sector                object
# Revenue               object
# Competitors           object
# Seniority               bool
# Salary Source         object
# min salary            object
# max salary            object
# average salary        object
# Company Age          float64
# dtype: object

# %% [markdown]
# ## THE END
